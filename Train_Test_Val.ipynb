# %%
import os
import numpy as np
import shutil
import pandas as pd


def train_test_split():
    print("########### Train Test Val Script started ###########")
    #data_csv = pd.read_csv("tea sickness dataset.csv") ##Use if you have classes saved in any .csv file

    root_dir = r'C:\Users\Akriti Gobhil\Downloads\tea sickness dataset\tea sickness dataset'
    classes_dir = [ 'algal leaf', 'Anthracnose', 'bird eye spot', 'brown blight', 'gray light', 'healthy', 'red leaf spot', 'white spot']

    #for name in data_csv['names'].unique()[:10]:
    #    classes_dir.append(name)

    processed_dir = root_dir

    val_ratio = 0.20
    test_ratio = 0.20

    for cls in classes_dir:
        # Creating partitions of the data after shuffeling
        print("$$$$$$$ Class Name " + cls + " $$$$$$$")
        src = processed_dir +"//" + cls  # Folder to copy images from

        allFileNames = os.listdir(src)
        np.random.shuffle(allFileNames)
        train_FileNames, val_FileNames, test_FileNames = np.split(np.array(allFileNames),
                                                                  [int(len(allFileNames) * (1 - (val_ratio + test_ratio))),
                                                                   int(len(allFileNames) * (1 - val_ratio)),
                                                                   ])

        train_FileNames = [src + '//' + name for name in train_FileNames.tolist()]
        val_FileNames = [src + '//' + name for name in val_FileNames.tolist()]
        test_FileNames = [src + '//' + name for name in test_FileNames.tolist()]

        print('Total images: '+ str(len(allFileNames)))
        print('Training: '+ str(len(train_FileNames)))
        print('Validation: '+  str(len(val_FileNames)))
        print('Testing: '+ str(len(test_FileNames)))

        # # Creating Train / Val / Test folders (One time use)
        os.makedirs(root_dir + '/train//' + cls)
        os.makedirs(root_dir + '/val//' + cls)
        os.makedirs(root_dir + '/test//' + cls)

        # Copy-pasting images
        for name in train_FileNames:
            shutil.copy(name, root_dir + '/train//' + cls)

        for name in val_FileNames:
            shutil.copy(name, root_dir + '/val//' + cls)

        for name in test_FileNames:
            shutil.copy(name, root_dir + '/test//' + cls)

    print("########### Train Test Val Script Ended ###########")

train_test_split()
# Out:
# ########### Train Test Val Script started ###########
# $$$$$$$ Class Name algal leaf $$$$$$$
# Total images: 113
# Training: 67
# Validation: 23
# Testing: 23
# $$$$$$$ Class Name Anthracnose $$$$$$$
# Total images: 100
# Training: 60
# Validation: 20
# Testing: 20
# $$$$$$$ Class Name bird eye spot $$$$$$$
# Total images: 100
# Training: 60
# Validation: 20
# Testing: 20
# $$$$$$$ Class Name brown blight $$$$$$$
# Total images: 113
# Training: 67
# Validation: 23
# Testing: 23
# $$$$$$$ Class Name gray light $$$$$$$
# Total images: 100
# Training: 60
# Validation: 20
# Testing: 20
# $$$$$$$ Class Name healthy $$$$$$$
# Total images: 74
# Training: 44
# Validation: 15
# Testing: 15
# $$$$$$$ Class Name red leaf spot $$$$$$$
# Total images: 144
# Training: 86
# Validation: 29
# Testing: 29
# $$$$$$$ Class Name white spot $$$$$$$
# Total images: 142
# Training: 85
# Validation: 28
# Testing: 29
# ########### Train Test Val Script Ended ###########
